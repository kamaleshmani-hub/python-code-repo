# %%
from operator import itemgetter

#Use Case 2: Student Result Classification
#a. Write a program that takes marks as input (initially as a string).
marks=input("marks:")
print(type(marks))


#B. Check if the value can be converted to float.
marks=float(input("marks:"))
print(type(marks))

#C. Then classify (try using if condition with the help of AI, however we will learn about if condition soon):
#marks >= 90 -->Outstanding
mark=90
if mark>=90:
 print("outstandind")

#Marks >= 75 --> Excellent
mark=77
if mark>=75:
 print("Excellent")

#Marks >= 50 --> Pass
mark=60
if mark>=50:
 print("pass")


#Marks < 50 --> Fail
mark=25
if mark<50:
    print("fail")


#D. If the input is not numeric, print:
 #Invalid marks entered — Please provide numeric input.
# Out:
# <class 'str'>
# <class 'float'>
# outstandind
# Excellent
# pass
# fail

# %%
#Use Case 3: Bug Fixing — Datatype Mismatch
#The below code is intended to calculate total price, but it has datatype errors. Fix it.
#Incorrect code:

item_name =input("Enter product name: ")
print(item_name)
print(type(item_name))

price=float(input("Enter price per item: "))
print(price)
print(type(price))

quantity =int(input("Enter quantity: "))
print(quantity)
#quantity=int(input("3: "))
#print(type(quantity))


#total_cost = price * quantity
total_cost = price * quantity
print(total_cost)

print("You purchased " + str(quantity) + " units of " +item_name)
print("Total payable: " + total_cost)
#Expected output after fixing:
#Enter product name: Notepad
#Enter price per item: 35.50
#Enter quantity: 3
#You purchased 3 units of Notepad
#Total payable: 106.5 INR
# Out:
# notepad
# <class 'str'>
# 35.5
# <class 'float'>
# 3
# 106.5
# You purchased 3 units of notepad
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 24
#      20 total_cost = price * quantity
#      21 print(total_cost)
#      22
#      23 print("You purchased " + str(quantity) + " units of " +item_name)
# ---> 24 print("Total payable: " + total_cost)
#      25 #Expected output after fixing:
#      26 #Enter product name: Notepad
#      27 #Enter price per item: 35.50
#
# TypeError: can only concatenate str (not "float") to str

# %%
#H. Python Operators Usecases
#Use Case 1: Internet Data Usage Calculator
#Write a program that asks the user for:
#Total monthly data limit (in GB)
monthly_data_limit_gb=200
data_used_so_far=75

#Calculate using arithmetic operators:
Remaining_data = monthly_data_limit_gb - data_used_so_far
#print
print(Remaining_data)

usage_percentage = (data_used_so_far /monthly_data_limit_gb) * 100
#Usage percentage rounded to 2 decimals
print("usage_percentage",round(usage_percentage,2))

if usage_percentage>=30:
    print("Warning: High usage, consider upgrading your plan.")

#Use Case 2: Shopping Discount Calculation
#Write a program that takes:
#Original price (float)
original_price=50.0
print(original_price)
print(type(original_price))
#Discount percent (int)
discount_percent=5

Discount_amount =original_price  * (discount_percent / 100)
print(Discount_amount)
Final_price = original_price -Discount_amount
print(Final_price)
# Out:
# 125
# usage_percentage 37.5
# Warning: High usage, consider upgrading your plan.
# 50.0
# <class 'float'>
# 2.5
# 47.5

# %%
#Use Case 3 (Bug Fixing): Logical and Comparison Operator Errors
#The following code should determine voting eligibility, but it contains operator mistakes. Fix it.
#Incorrect code:
age=int(input("Enter age: "))
print(type(age))
citizen = input("Are you an Indian citizen? (yes/no)")

if age>= 18 and citizen == "yes":
     print("Eligible to vote")

else:
     print("Not eligible to vote")

#example 2
age=int(input("Enter age: "))
print(type(age))
citizen = input("Are you an Indian citizen? (yes/no)")

if age>= 18 and citizen == "yes":
     print("Eligible to vote")

else:
     print("Not eligible to vote")
# Out:
# <class 'int'>
# Eligible to vote
# <class 'int'>
# Not eligible to vote

# %%
#I. Conditional Structure
#Use Case 1: Banking Eligibility Check
#Write a program that asks the user for:
age=20
Monthly_income=12000


#condition
if age <18:
    print("Not eligible for a bank account.")
elif age >= 18 and Monthly_income < 15000:
    print("Eligible for basic savings account.")
elif age >= 18 and 15000 <= Monthly_income <= 50000:
    print("Eligible for savings + salary account.")
elif age >= 18 and Monthly_income >50000:
    print("Eligible for premium account.")
else:
    print("not eligible for any bank accounts.")
# Out:
# Eligible for basic savings account.

# %%
'''Use Case 2: Check room availability
-Check room availability
    - If available:
        - If guest is VIP
            → Offer complimentary upgrade
        - Else if member 5+ years
            → Offer discount
        - Else
            → Standard price
    - Else:
 Show: "No rooms available"
'''

#example 1
guest_age=4
guest_status=" not Vip"
room_available="yes"
discount_percent=5
room_price=2500

if guest_age>5 and "vip":
    discount_amount=room_price*discount_percent/100
    room_price=room_price-discount_amount
    print("beach view rooms are available at "
          + room_price + "only for vip guests")
else:
    print("rooms are available with standard price")


#example 2#
guest_age=15
guest_status="Vip"
room_available="yes"

if room_available=="yes" and guest_age==15 and guest_status=="Vip":
    print(" beach view rooms are available only for vip guests")
else:
    print("rooms are not available")

#example 3
guest_age<5
guest_status="Vip"
room_available="yes"

if room_available=="yes" and guest_age<5 and guest_status=="Vip":
    print("rooms are available only for 5+ years")

else:
    print("rooms are not available at this time")
# Out:
# rooms are available with standard price
#  beach view rooms are available only for vip guests
# rooms are not available at this time

# %%
'''Use Case 3 (Bug Fixing): Nested Condition Logic Issue
Fix the following code so that it correctly determines whether the entered temperature indicates normal, fever, or high fever.
Incorrect code:
temp = input("Enter body temperature in Celsius: ")
if temp < "37":
 print("Normal temperature")
 elif temp > "37" and temp < "39":
 print("Fever")
 else
 print("High fever")
Expected behavior:
Convert temperature to float before comparison.


Conditions should print:
 Normal temperature (less than 37)
 Fever (between 37 and 39)
 High fever (39 and above)
'''
#example1
temp=float(input("Enter body temperature in Celsius: "))
if temp <37:
    print("normal Fever")
elif temp > 37 and temp < 39:
    print("Fever")
else:
    print("High fever")

#example1
temp = float(input("Enter body temperature in Celsius: "))
if temp < 37:
    print("normal Fever")
elif temp > 37 and temp < 39:
    print("Fever")
else:
    print("High fever")

#example 3
temp = float(input("Enter body temperature in Celsius: "))
if temp < 37:
    print("normal Fever")
elif temp > 37 and temp < 39:
    print("Fever")
else:
    print("High fever")
# Out:
# normal Fever
# Fever
# High fever
